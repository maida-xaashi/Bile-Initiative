# %% [markdown]
# <a href="https://colab.research.google.com/github/maida-xaashi/Bile-Initiative/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data= pd.read_csv('student-por.csv',sep=';')

# %%
data["at_risk"] = (data["G3"] <= 10).astype(int)

# %%
features=["studytime","failures","schoolsup","famsup", "activities","higher","internet",
          "famrel","health","absences"
]
x=data[features].copy()

# %%
Y=data["at_risk"]

# %%
Y.value_counts()
# Out:
# at_risk
# 0    452
# 1    197
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

Y.value_counts().plot(kind="bar")
plt.xlabel("at_risk")
plt.ylabel("count")
plt.title("Class distribution")
plt.show()
